# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * Northern vs. Southern Hemispheres: One might expect temperatures to decline predictably with distance from the equator, however it seems that the northern hemisphere has more extremes, at least at this time of year.  The first graph, which is based on maximum temperatures, indicates that the northern half of the planet gets colder quicker. It also seems that a greater number of cities are in humid, windy and cloudy conditions than the southern hemisphere. This could be because of earth's tilt, however more analysis is needed to be sure.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import config

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %%
cities_df = pd.DataFrame(cities)

cities_df.head()
# Out:
#             0
# 0     mataura
# 1      olinda
# 2       bluff
# 3  bredasdorp
# 4   bathsheba

# %%
cities_df.columns = ["City"]
cities_df.head()
# Out:
#          City
# 0     mataura
# 1      olinda
# 2       bluff
# 3  bredasdorp
# 4   bathsheba

# %%
#empty columns for dataframe
cities_df["Country"] = ""
cities_df["City ID"] = ""
cities_df['Latitude'] = ""
cities_df['Longitude'] = ""
cities_df['Temperature (F)'] = ""
cities_df['Humidity (%)'] = ""
cities_df['Cloudiness (%)'] = ""
cities_df['Wind Speed (mph)'] = ""

# %%
cities_df.head()
# Out:
#          City Country City ID Latitude Longitude Temperature (F) Humidity (%)  \
# 0     mataura
# 1      olinda
# 2       bluff
# 3  bredasdorp
# 4   bathsheba
#
#   Cloudiness (%) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed '(with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
api_key = config.weather_api


# Build partial query URL
#{url}appid={api_key}&units={units}&q=
query_url = f"{url}&units={units}&APPID={api_key}&q="
query_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q='

# %%
#api call from open weather
print(f"Beginning Data Retrieval")
print(f"-------------------------------")



record = 1

for index, row in cities_df.iterrows():
    print(row['City'])
    try:


        cities_url = query_url + row["City"]
        cities_response = requests.get(cities_url).json()



        #city.append(response["name"])
        row["Country"] = cities_response["sys"]["country"]
        row["City ID"] = cities_response["sys"]["id"]
        row["Latitude"] = cities_response["coord"]["lat"]
        row["Longitude"] = cities_response["coord"]["lon"]
        row['Temperature (F)'] = cities_response["main"]["temp_max"]
        row['Humidity (%)'] = cities_response["main"]["humidity"]
        row['Cloudiness (%)'] = cities_response["clouds"]["all"]
        row['Wind Speed (mph)'] = cities_response["wind"]["speed"]




        record += 1 



        #print(city+"&id="+str(cities_url))
        print(cities_url)


    except:
        print(f"Data is missing, skipping")
        continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# mataura
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mataura
# olinda
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=olinda
# bluff
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bluff
# bredasdorp
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bredasdorp
# bathsheba
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bathsheba
# palencia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=palencia
# albany
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=albany
# rikitea
# Data is missing, skipping
# atuona
# Data is missing, skipping
# barrow
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=barrow
# marawi
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=marawi
# kapaa
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kapaa
# fort nelson
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=fort nelson
# abu samrah
# Data is missing, skipping
# mobaye
# Data is missing, skipping
# tasiilaq
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tasiilaq
# jamestown
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=jamestown
# ilulissat
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ilulissat
# ribeira grande
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ribeira grande
# dingle
# Data is missing, skipping
# nekhayevskiy
# Data is missing, skipping
# nacala
# Data is missing, skipping
# hilo
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hilo
# ushuaia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ushuaia
# nemuro
# Data is missing, skipping
# sungai besar
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sungai besar
# camacha
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=camacha
# cape town
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=cape town
# isangel
# Data is missing, skipping
# ancud
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ancud
# thompson
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=thompson
# busselton
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=busselton
# aklavik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=aklavik
# lolua
# Data is missing, skipping
# hermanus
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hermanus
# alta floresta
# Data is missing, skipping
# rio muerto
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=rio muerto
# naze
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=naze
# illoqqortoormiut
# Data is missing, skipping
# tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tuktoyaktuk
# port elizabeth
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=port elizabeth
# nizhneyansk
# Data is missing, skipping
# mar del plata
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mar del plata
# leningradskiy
# Data is missing, skipping
# arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=arraial do cabo
# port lavaca
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=port lavaca
# marcona
# Data is missing, skipping
# chokurdakh
# Data is missing, skipping
# port alfred
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=port alfred
# saint-philippe
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=saint-philippe
# clyde river
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=clyde river
# saskylakh
# Data is missing, skipping
# zhigansk
# Data is missing, skipping
# acapulco
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=acapulco
# hasaki
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hasaki
# lisala
# Data is missing, skipping
# tiksi
# Data is missing, skipping
# irituia
# Data is missing, skipping
# gorontalo
# Data is missing, skipping
# carnarvon
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=carnarvon
# pueblo nuevo
# Data is missing, skipping
# mecca
# Data is missing, skipping
# castro
# Data is missing, skipping
# mocuba
# Data is missing, skipping
# taolanaro
# Data is missing, skipping
# sitka
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sitka
# katsuura
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=katsuura
# hobart
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hobart
# maebaru
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=maebaru
# yantal
# Data is missing, skipping
# faanui
# Data is missing, skipping
# vaini
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=vaini
# puerto ayora
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=puerto ayora
# dikson
# Data is missing, skipping
# pasighat
# Data is missing, skipping
# longyearbyen
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=longyearbyen
# lata
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lata
# hun
# Data is missing, skipping
# new norfolk
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=new norfolk
# san patricio
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=san patricio
# lavrentiya
# Data is missing, skipping
# biysk
# Data is missing, skipping
# broome
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=broome
# nagato
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nagato
# geraldton
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=geraldton
# diego de almagro
# Data is missing, skipping
# tari
# Data is missing, skipping
# punta arenas
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=punta arenas
# cayenne
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=cayenne
# coihaique
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=coihaique
# saldanha
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=saldanha
# saint george
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=saint george
# pahrump
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=pahrump
# falealupo
# Data is missing, skipping
# vaitape
# Data is missing, skipping
# victoria
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=victoria
# grindavik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=grindavik
# heihe
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=heihe
# jhudo
# Data is missing, skipping
# tabarqah
# Data is missing, skipping
# hithadhoo
# Data is missing, skipping
# presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=presidencia roque saenz pena
# atasu
# Data is missing, skipping
# qaanaaq
# Data is missing, skipping
# amderma
# Data is missing, skipping
# atambua
# Data is missing, skipping
# montague
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=montague
# ishigaki
# Data is missing, skipping
# chunskiy
# Data is missing, skipping
# jardim de piranhas
# Data is missing, skipping
# rincon
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=rincon
# caribou
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=caribou
# kahului
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kahului
# marzuq
# Data is missing, skipping
# eureka
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=eureka
# vredendal
# Data is missing, skipping
# hay river
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hay river
# paris
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=paris
# paamiut
# Data is missing, skipping
# severo-kurilsk
# Data is missing, skipping
# deputatskiy
# Data is missing, skipping
# yar-sale
# Data is missing, skipping
# yamada
# Data is missing, skipping
# santa lucia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=santa lucia
# bonao
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bonao
# bighapur
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bighapur
# ballina
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ballina
# wynyard
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=wynyard
# kadiri
# Data is missing, skipping
# mangrol
# Data is missing, skipping
# miracema do tocantins
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=miracema do tocantins
# yakima
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=yakima
# karakendzha
# Data is missing, skipping
# aberdeen
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=aberdeen
# kovur
# Data is missing, skipping
# talnakh
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=talnakh
# sisimiut
# Data is missing, skipping
# bandarbeyla
# Data is missing, skipping
# cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=cabo san lucas
# robertsport
# Data is missing, skipping
# bengkulu
# Data is missing, skipping
# iganga
# Data is missing, skipping
# natal
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=natal
# tonantins
# Data is missing, skipping
# kysyl-syr
# Data is missing, skipping
# yomitan
# Data is missing, skipping
# hami
# Data is missing, skipping
# plainview
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=plainview
# ponta do sol
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ponta do sol
# dovers
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=dovers
# henties bay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=henties bay
# linchuan
# Data is missing, skipping
# lerwick
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lerwick
# barentsburg
# Data is missing, skipping
# constitucion
# Data is missing, skipping
# namibe
# Data is missing, skipping
# mersin
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mersin
# komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=komsomolskiy
# khatanga
# Data is missing, skipping
# butaritari
# Data is missing, skipping
# renqiu
# Data is missing, skipping
# norman wells
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=norman wells
# coahuayana
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=coahuayana
# grand forks
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=grand forks
# miguel alves
# Data is missing, skipping
# dahuk
# Data is missing, skipping
# pangnirtung
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=pangnirtung
# husavik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=husavik
# chernyshevskiy
# Data is missing, skipping
# narsaq
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=narsaq
# upernavik
# Data is missing, skipping
# dongsheng
# Data is missing, skipping
# kruisfontein
# Data is missing, skipping
# hastings
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hastings
# akhmeta
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=akhmeta
# lashio
# Data is missing, skipping
# kaitangata
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kaitangata
# penzance
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=penzance
# nyimba
# Data is missing, skipping
# tuensang
# Data is missing, skipping
# chervone
# Data is missing, skipping
# golspie
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=golspie
# caravelas
# Data is missing, skipping
# vaitupu
# Data is missing, skipping
# harper
# Data is missing, skipping
# korla
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=korla
# saleaula
# Data is missing, skipping
# bull savanna
# Data is missing, skipping
# aswan
# Data is missing, skipping
# cidreira
# Data is missing, skipping
# ermelo
# Data is missing, skipping
# chimore
# Data is missing, skipping
# shetpe
# Data is missing, skipping
# belushya guba
# Data is missing, skipping
# thanh hoa
# Data is missing, skipping
# mehamn
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mehamn
# corinto
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=corinto
# balikpapan
# Data is missing, skipping
# chateauneuf-les-martigues
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=chateauneuf-les-martigues
# nikolskoye
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nikolskoye
# mandera
# Data is missing, skipping
# palabuhanratu
# Data is missing, skipping
# mackay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mackay
# craig
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=craig
# port blair
# Data is missing, skipping
# pacific grove
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=pacific grove
# ituni
# Data is missing, skipping
# phan thiet
# Data is missing, skipping
# half moon bay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=half moon bay
# provideniya
# Data is missing, skipping
# codrington
# Data is missing, skipping
# lompoc
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lompoc
# tuatapere
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tuatapere
# jacmel
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=jacmel
# zabol
# Data is missing, skipping
# meulaboh
# Data is missing, skipping
# teguldet
# Data is missing, skipping
# borovskoy
# Data is missing, skipping
# lovozero
# Data is missing, skipping
# attawapiskat
# Data is missing, skipping
# alofi
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=alofi
# chikoy
# Data is missing, skipping
# gimli
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=gimli
# klaksvik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=klaksvik
# khandyga
# Data is missing, skipping
# soyo
# Data is missing, skipping
# atlantic city
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=atlantic city
# severnyy
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=severnyy
# gizo
# Data is missing, skipping
# semnan
# Data is missing, skipping
# santa cruz del sur
# Data is missing, skipping
# ormara
# Data is missing, skipping
# le port
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=le port
# edd
# Data is missing, skipping
# tsienyane
# Data is missing, skipping
# oranjemund
# Data is missing, skipping
# georgetown
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=georgetown
# stoyba
# Data is missing, skipping
# hobyo
# Data is missing, skipping
# riberalta
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=riberalta
# verkhnyaya inta
# Data is missing, skipping
# sao filipe
# Data is missing, skipping
# gamba
# Data is missing, skipping
# lalibela
# Data is missing, skipping
# silopi
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=silopi
# margate
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=margate
# mys shmidta
# Data is missing, skipping
# mayumba
# Data is missing, skipping
# suntar
# Data is missing, skipping
# ostrovnoy
# Data is missing, skipping
# mentok
# Data is missing, skipping
# iqaluit
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=iqaluit
# lorengau
# Data is missing, skipping
# mahebourg
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mahebourg
# east london
# Data is missing, skipping
# tsihombe
# Data is missing, skipping
# hauterive
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hauterive
# williston
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=williston
# wahran
# Data is missing, skipping
# venado tuerto
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=venado tuerto
# esperance
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=esperance
# taoudenni
# Data is missing, skipping
# fortuna
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=fortuna
# skalistyy
# Data is missing, skipping
# barceloneta
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=barceloneta
# inta
# Data is missing, skipping
# tahe
# Data is missing, skipping
# kodiak
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kodiak
# yellowknife
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=yellowknife
# harnosand
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=harnosand
# yuci
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=yuci
# airai
# Data is missing, skipping
# lhuntshi
# Data is missing, skipping
# souillac
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=souillac
# lebu
# Data is missing, skipping
# sosnovo-ozerskoye
# Data is missing, skipping
# san ramon
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=san ramon
# hamilton
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hamilton
# bethel
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bethel
# kavieng
# Data is missing, skipping
# formoso do araguaia
# Data is missing, skipping
# guaruja
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=guaruja
# dudinka
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=dudinka
# ocos
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ocos
# vilyuysk
# Data is missing, skipping
# kikwit
# Data is missing, skipping
# kargapolye
# Data is missing, skipping
# vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=vestmannaeyjar
# samarai
# Data is missing, skipping
# rajpur
# Data is missing, skipping
# daru
# Data is missing, skipping
# avarua
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=avarua
# camana
# Data is missing, skipping
# rawson
# Data is missing, skipping
# bambous virieux
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bambous virieux
# pevek
# Data is missing, skipping
# rodrigues alves
# Data is missing, skipping
# bay roberts
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=bay roberts
# chuy
# Data is missing, skipping
# rudbar
# Data is missing, skipping
# zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=zhezkazgan
# santa cruz
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=santa cruz
# kavaratti
# Data is missing, skipping
# sentyabrskiy
# Data is missing, skipping
# petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=petropavlovsk-kamchatskiy
# grootfontein
# Data is missing, skipping
# carnduff
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=carnduff
# tautira
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tautira
# sioux lookout
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sioux lookout
# oliveira dos brejinhos
# Data is missing, skipping
# komsomolsk-na-amure
# Data is missing, skipping
# ahipara
# Data is missing, skipping
# warqla
# Data is missing, skipping
# juegang
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=juegang
# rio grande
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=rio grande
# ulladulla
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ulladulla
# thiruvananthapuram
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=thiruvananthapuram
# pozo colorado
# Data is missing, skipping
# lac du bonnet
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lac du bonnet
# ainring
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ainring
# pangai
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=pangai
# bengkalis
# Data is missing, skipping
# qandala
# Data is missing, skipping
# tahta
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tahta
# muros
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=muros
# lagoa
# Data is missing, skipping
# lasa
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lasa
# yadrin
# Data is missing, skipping
# ust-nera
# Data is missing, skipping
# churapcha
# Data is missing, skipping
# the valley
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=the valley
# hidalgo
# Data is missing, skipping
# kourou
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kourou
# tikrit
# Data is missing, skipping
# oga
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=oga
# faya
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=faya
# teseney
# Data is missing, skipping
# broken hill
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=broken hill
# tandil
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tandil
# sembe
# Data is missing, skipping
# murgab
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=murgab
# qeshm
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=qeshm
# balkhash
# Data is missing, skipping
# tecoanapa
# Data is missing, skipping
# diamantino
# Data is missing, skipping
# keflavik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=keflavik
# puerto narino
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=puerto narino
# kemijarvi
# Data is missing, skipping
# luderitz
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=luderitz
# samusu
# Data is missing, skipping
# krasnoselkup
# Data is missing, skipping
# ewa beach
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ewa beach
# tiznit
# Data is missing, skipping
# clovis
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=clovis
# el alto
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=el alto
# akyab
# Data is missing, skipping
# victor harbor
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=victor harbor
# bubaque
# Data is missing, skipping
# santa cruz del norte
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=santa cruz del norte
# itambacuri
# Data is missing, skipping
# bilma
# Data is missing, skipping
# melilla
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=melilla
# mount gambier
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mount gambier
# hualmay
# Data is missing, skipping
# masty
# Data is missing, skipping
# zhanakorgan
# Data is missing, skipping
# riyadh
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=riyadh
# toora-khem
# Data is missing, skipping
# dunmore east
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=dunmore east
# vardo
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=vardo
# san cristobal
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=san cristobal
# manaure
# Data is missing, skipping
# nanortalik
# Data is missing, skipping
# suez
# Data is missing, skipping
# wanlaweyn
# Data is missing, skipping
# dalbandin
# Data is missing, skipping
# balad
# Data is missing, skipping
# bac lieu
# Data is missing, skipping
# chapais
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=chapais
# paka
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=paka
# syracuse
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=syracuse
# cururupu
# Data is missing, skipping
# devrek
# Data is missing, skipping
# tura
# Data is missing, skipping
# burevestnik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=burevestnik
# phan rang
# Data is missing, skipping
# wattegama
# Data is missing, skipping
# hokitika
# Data is missing, skipping
# launceston
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=launceston
# grand river south east
# Data is missing, skipping
# nome
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nome
# tchibanga
# Data is missing, skipping
# salalah
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=salalah
# sola
# Data is missing, skipping
# sakaiminato
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sakaiminato
# kontagora
# Data is missing, skipping
# hof
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hof
# padang
# Data is missing, skipping
# palembang
# Data is missing, skipping
# abha
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=abha
# itarema
# Data is missing, skipping
# borogontsy
# Data is missing, skipping
# payson
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=payson
# maragogi
# Data is missing, skipping
# san policarpo
# Data is missing, skipping
# alyangula
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=alyangula
# guerrero negro
# Data is missing, skipping
# sinnamary
# Data is missing, skipping
# plymouth
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=plymouth
# hervey bay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=hervey bay
# laguna
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=laguna
# hambantota
# Data is missing, skipping
# barrhead
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=barrhead
# havoysund
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=havoysund
# tabou
# Data is missing, skipping
# pasil
# Data is missing, skipping
# roswell
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=roswell
# chulym
# Data is missing, skipping
# kushiro
# Data is missing, skipping
# high level
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=high level
# olafsvik
# Data is missing, skipping
# cockburn town
# Data is missing, skipping
# hudson bay
# Data is missing, skipping
# nelipyno
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nelipyno
# shahr-e kord
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=shahr-e kord
# naushki
# Data is missing, skipping
# hailar
# Data is missing, skipping
# sidrolandia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sidrolandia
# nizwa
# Data is missing, skipping
# pula
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=pula
# makakilo city
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=makakilo city
# malwan
# Data is missing, skipping
# sogdiondon
# Data is missing, skipping
# russell
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=russell
# kumluca
# Data is missing, skipping
# frantiskovy lazne
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=frantiskovy lazne
# riachao das neves
# Data is missing, skipping
# jalu
# Data is missing, skipping
# port-gentil
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=port-gentil
# angangxi
# Data is missing, skipping
# kharp
# Data is missing, skipping
# seoul
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=seoul
# sapozhok
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sapozhok
# ixtapa
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ixtapa
# clarence town
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=clarence town
# halifax
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=halifax
# eregli
# Data is missing, skipping
# upata
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=upata
# leh
# Data is missing, skipping
# williams lake
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=williams lake
# arman
# Data is missing, skipping
# honiara
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=honiara
# vao
# Data is missing, skipping
# hit
# Data is missing, skipping
# sorvag
# Data is missing, skipping
# ambilobe
# Data is missing, skipping
# chlorakas
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=chlorakas
# altamira
# Data is missing, skipping
# nizhniye sergi
# Data is missing, skipping
# bengbu
# Data is missing, skipping
# acarau
# Data is missing, skipping
# cam ranh
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=cam ranh
# gambela
# Data is missing, skipping
# aykhal
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=aykhal
# blind river
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=blind river
# nago
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nago
# buchanan
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=buchanan
# saint-joseph
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=saint-joseph
# dawei
# Data is missing, skipping
# tidore
# Data is missing, skipping
# trondheim
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=trondheim
# kovernino
# Data is missing, skipping
# langxiang
# Data is missing, skipping
# ndola
# Data is missing, skipping
# napier
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=napier
# travesia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=travesia
# richards bay
# Data is missing, skipping
# nortelandia
# Data is missing, skipping
# darovskoy
# Data is missing, skipping
# erdenet
# Data is missing, skipping
# talawdi
# Data is missing, skipping
# mercedes
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mercedes
# sorata
# Data is missing, skipping
# marsaxlokk
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=marsaxlokk
# camopi
# Data is missing, skipping
# arlit
# Data is missing, skipping
# picos
# Data is missing, skipping
# quatre cocos
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=quatre cocos
# manacapuru
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=manacapuru
# satuk
# Data is missing, skipping
# berbera
# Data is missing, skipping
# viligili
# Data is missing, skipping
# poum
# Data is missing, skipping
# nan
# Data is missing, skipping
# mitu
# Data is missing, skipping
# niteroi
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=niteroi
# finschhafen
# Data is missing, skipping
# burnie
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=burnie
# ambanja
# Data is missing, skipping
# clinton
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=clinton
# utete
# Data is missing, skipping
# tuy hoa
# Data is missing, skipping
# torbat-e jam
# Data is missing, skipping
# sur
# Data is missing, skipping
# marathon
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=marathon
# nelson bay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=nelson bay
# buala
# Data is missing, skipping
# kalmunai
# Data is missing, skipping
# praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=praia da vitoria
# port lincoln
# Data is missing, skipping
# freeport
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=freeport
# bam
# Data is missing, skipping
# kudahuvadhoo
# Data is missing, skipping
# namatanai
# Data is missing, skipping
# vanavara
# Data is missing, skipping
# sauce
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sauce
# new iberia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=new iberia
# rio gallegos
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=rio gallegos
# west bay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=west bay
# la troncal
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=la troncal
# port said
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=port said
# muyezerskiy
# Data is missing, skipping
# safaga
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=safaga
# balgazyn
# Data is missing, skipping
# mombasa
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mombasa
# labuhan
# Data is missing, skipping
# kloulklubed
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kloulklubed
# te anau
# Data is missing, skipping
# frederick
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=frederick
# antofagasta
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=antofagasta
# sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=sao joao da barra
# vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=vila franca do campo
# ramgarh
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ramgarh
# toftir
# Data is missing, skipping
# dujuma
# Data is missing, skipping
# katherine
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=katherine
# patnos
# Data is missing, skipping
# brae
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=brae
# zlitan
# Data is missing, skipping
# beziers
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=beziers
# jesus carranza
# Data is missing, skipping
# berlevag
# Data is missing, skipping
# kita
# Data is missing, skipping
# coruripe
# Data is missing, skipping
# dalvik
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=dalvik
# konosha
# Data is missing, skipping
# kjollefjord
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kjollefjord
# prince rupert
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=prince rupert
# limoeiro do ajuru
# Data is missing, skipping
# pontes e lacerda
# Data is missing, skipping
# solnechnyy
# Data is missing, skipping
# puerto quijarro
# Data is missing, skipping
# kieta
# Data is missing, skipping
# merauke
# Data is missing, skipping
# porto novo
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=porto novo
# kiama
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kiama
# karak
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=karak
# pak phanang
# Data is missing, skipping
# anadyr
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=anadyr
# mount isa
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=mount isa
# kamenka
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=kamenka
# kraksaan
# Data is missing, skipping
# pandamatenga
# Data is missing, skipping
# maralal
# Data is missing, skipping
# tromso
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=tromso
# hirara
# Data is missing, skipping
# addanki
# Data is missing, skipping
# kodinsk
# Data is missing, skipping
# kolomak
# Data is missing, skipping
# vanimo
# Data is missing, skipping
# makarov
# Data is missing, skipping
# agirish
# Data is missing, skipping
# lincoln
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=lincoln
# griffith
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=griffith
# filadelfia
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=filadelfia
# san quintin
# Data is missing, skipping
# grong
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=grong
# quelimane
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=quelimane
# adrar
# Data is missing, skipping
# umm lajj
# Data is missing, skipping
# granada
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=granada
# wundanyi
# Data is missing, skipping
# westport
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=westport
# rizhao
# Data is missing, skipping
# bogatyye saby
# Data is missing, skipping
# haicheng
# Data is missing, skipping
# santa vitoria do palmar
# Data is missing, skipping
# omsukchan
# Data is missing, skipping
# cherskiy
# Data is missing, skipping
# namie
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=namie
# sinjah
# Data is missing, skipping
# rio bueno
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=rio bueno
# zhanatas
# Data is missing, skipping
# torbay
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=torbay
# chandler
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=chandler
# tonj
# Data is missing, skipping
# villarrica
# Data is missing, skipping
# comodoro rivadavia
# Data is missing, skipping
# sambava
# Data is missing, skipping
# hongjiang
# Data is missing, skipping
# tekkalakota
# Data is missing, skipping
# great yarmouth
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=great yarmouth
# ambon
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=ambon
# sao miguel do guama
# Data is missing, skipping
# marsh harbour
# Data is missing, skipping
# ambunti
# Data is missing, skipping
# peringat
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=peringat
# vrises
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=vrises
# whitecourt
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=whitecourt
# saint-pierre
# http://api.openweathermap.org/data/2.5/weather?&units=imperial&APPID=3974be9fa6e0d0ba48004fb47c9abbeb&q=saint-pierre
# garh maharaja
# Data is missing, skipping

# %%
# Remove empty cells. 
#convert string to np.nan
cities_df["Temperature (F)"].replace('', np.nan, inplace=True)
cities_df["City ID"].replace('', np.nan, inplace=True)
cities_df["Latitude"].replace('', np.nan, inplace=True)
cities_df["Longitude"].replace('', np.nan, inplace=True)
cities_df["Humidity (%)"].replace('', np.nan, inplace=True)
cities_df["Cloudiness (%)"].replace('', np.nan, inplace=True)
cities_df["Wind Speed (mph)"].replace('', np.nan, inplace=True)
cities_df.head(10)
# Out:
#          City Country    City ID  Latitude  Longitude  Temperature (F)  \
# 0     mataura      NZ  2008959.0    -46.19     168.86             39.0
# 1      olinda      BR     8426.0     -8.01     -34.86             80.6
# 2       bluff      NZ  2008959.0    -46.60     168.33             39.0
# 3  bredasdorp      ZA     1966.0    -34.53      20.04             55.4
# 4   bathsheba      BB     8772.0     13.22     -59.52             87.8
# 5    palencia      ES    67672.0     42.42      -4.50             81.0
# 6      albany      US    19530.0     42.60     -73.97             84.0
# 7     rikitea      PF        NaN       NaN        NaN              NaN
# 8      atuona      PF        NaN       NaN        NaN              NaN
# 9      barrow      US     7649.0     71.29    -156.79             39.2
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          83.0            87.0              3.00
# 1          65.0            75.0              5.82
# 2          83.0            91.0              3.00
# 3          71.0             0.0              6.93
# 4          66.0            75.0             24.16
# 5          24.0            86.0             12.91
# 6          31.0            12.0              3.00
# 7           NaN             NaN               NaN
# 8           NaN             NaN               NaN
# 9          93.0            90.0             10.29

# %% [markdown]
# ### Save to CSV

# %%
clean_data_df = cities_df.dropna(how = 'any')

clean_data_df.head(10)
# Out:
#           City Country    City ID  Latitude  Longitude  Temperature (F)  \
# 0      mataura      NZ  2008959.0    -46.19     168.86            39.00
# 1       olinda      BR     8426.0     -8.01     -34.86            80.60
# 2        bluff      NZ  2008959.0    -46.60     168.33            39.00
# 3   bredasdorp      ZA     1966.0    -34.53      20.04            55.40
# 4    bathsheba      BB     8772.0     13.22     -59.52            87.80
# 5     palencia      ES    67672.0     42.42      -4.50            81.00
# 6       albany      US    19530.0     42.60     -73.97            84.00
# 9       barrow      US     7649.0     71.29    -156.79            39.20
# 10      marawi      PH  2007154.0      8.00     124.29            75.99
# 11       kapaa      US     7873.0     22.08    -159.32            77.00
#
#     Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0           83.0            87.0              3.00
# 1           65.0            75.0              5.82
# 2           83.0            91.0              3.00
# 3           71.0             0.0              6.93
# 4           66.0            75.0             24.16
# 5           24.0            86.0             12.91
# 6           31.0            12.0              3.00
# 9           93.0            90.0             10.29
# 10          93.0           100.0              4.00
# 11          78.0             1.0             12.75

# %%
#Save dataframe to csv
clean_data_df.to_csv('cities_edited.csv', index=None)
# Display data frame head 
clean_data_df.head()
# Out:
#          City Country    City ID  Latitude  Longitude  Temperature (F)  \
# 0     mataura      NZ  2008959.0    -46.19     168.86             39.0
# 1      olinda      BR     8426.0     -8.01     -34.86             80.6
# 2       bluff      NZ  2008959.0    -46.60     168.33             39.0
# 3  bredasdorp      ZA     1966.0    -34.53      20.04             55.4
# 4   bathsheba      BB     8772.0     13.22     -59.52             87.8
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          83.0            87.0              3.00
# 1          65.0            75.0              5.82
# 2          83.0            91.0              3.00
# 3          71.0             0.0              6.93
# 4          66.0            75.0             24.16

# %%
df=pd.read_csv('cities_edited.csv', index_col=None)

# %%
df.head()
# Out:
#          City Country    City ID  Latitude  Longitude  Temperature (F)  \
# 0     mataura      NZ  2008959.0    -46.19     168.86             39.0
# 1      olinda      BR     8426.0     -8.01     -34.86             80.6
# 2       bluff      NZ  2008959.0    -46.60     168.33             39.0
# 3  bredasdorp      ZA     1966.0    -34.53      20.04             55.4
# 4   bathsheba      BB     8772.0     13.22     -59.52             87.8
#
#    Humidity (%)  Cloudiness (%)  Wind Speed (mph)
# 0          83.0            87.0              3.00
# 1          65.0            75.0              5.82
# 2          83.0            91.0              3.00
# 3          71.0             0.0              6.93
# 4          66.0            75.0             24.16

# %% [markdown]
# ### Plotting the Data & Saving Images

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# %matplotlib inline
plt.rcParams["figure.figsize"] = [10, 8]

# %%
x=df["Latitude"]
y=df["Temperature (F)"]
plt.scatter(x, y, alpha = 0.75, linewidth = 1.5, color='firebrick',)

#Add title, x axis label and y axis label.
plt.title("Latitude vs Temps")
plt.xlabel("Latitude")
plt.ylabel("Temperature")
plt.grid(True)
plt.savefig('images/temperature.png')
#Show plot.
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df["Latitude"], df["Humidity (%)"], color = "limegreen", alpha = 0.75, linewidth = 1.5)

#Add title, x axis label and y axis label.
plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)
plt.tight_layout()
#save fig
plt.savefig("images/humidity.png")
#Show plot.
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df["Latitude"], df["Cloudiness (%)"], color = "dodgerblue", alpha = 0.75, linewidth = 1.5)

#Add title, x axis label and y axis label.
plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True)
plt.tight_layout()
#save plot
plt.savefig("images/cloudiness.png")
#Show plot.
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df["Latitude"], df['Wind Speed (mph)'], color = "darkorange", alpha = 1, linewidth = 1.5)

#Add title, x axis label and y axis label.
plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
plt.grid(True)
plt.tight_layout()
#save plot
plt.savefig("images/windspeed")
#Show plot.
plt.show()

# %%
from scipy.stats import linregress

# %%
# Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=15,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
n_h_df = df.loc[(df['Latitude'] >= 0)]
s_h_df = df.loc[(df['Latitude'] < 0)]

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ##### Low r values suggest that there is not much going on here in terms of correlation.

# %% [markdown]
# #### Maximum Temps vs Lat

# %%
#max temp northern hemisphere
x_values = n_h_df["Latitude"]
y_values = n_h_df["Temperature (F)"]
plot_linear_regression(x_values, y_values, 'Temperature (F)',(6,30))
# Out:
# The r-squared is: 0.4933530718066831

# %%
#max temp southern
x_values = s_h_df["Latitude"]
y_values = s_h_df["Humidity (%)"]
plot_linear_regression(x_values, y_values, 'Humidity',(6,30))
# Out:
# The r-squared is: 0.014056033344803778

# %% [markdown]
# #### Humidity vs Lat

# %%
# Northern Hemisphere
x_values = n_h_df["Latitude"]
y_values = n_h_df["Humidity (%)"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.001353297034635357

# %%
# Southern Hemisphere
x_values = s_h_df["Latitude"]
y_values = s_h_df["Humidity (%)"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.014056033344803778

# %% [markdown]
# #### Wind vs Latitude

# %%
x_values = n_h_df["Latitude"]
y_values = n_h_df["Wind Speed (mph)"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.01464289755123251

# %%
x_values = s_h_df["Latitude"]
y_values = s_h_df["Wind Speed (mph)"]
plot_linear_regression(x_values, y_values, 'Humidity',(40,10))
# Out:
# The r-squared is: 0.030228217522169924

# %% [markdown]
# ## Humidity GMap

# %%
import requests
import gmaps
import os
from config import goog_key

# %%
# Configure gmaps
gmaps.configure(api_key=goog_key)

# %%
# Heatmap of humidity
locations = df[["Latitude", "Longitude"]]
humidity = df["Humidity (%)"]
fig = gmaps.figure()
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, dissipating=False, max_intensity=200, point_radius=3)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
